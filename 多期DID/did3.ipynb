# %%
import os
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from datetime import datetime

# 创建输出目录，如果不存在
output_dir = 'output_directory'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 生成带时间戳的文件名
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
output_file = os.path.join(output_dir, f'DiD_model_results_{timestamp}.xlsx')

# 读取交通事故数据
traffic_data_file = 'TrafficAccident.xlsx'  # 根据实际路径修改
traffic_df = pd.read_excel(traffic_data_file)

# 检查交通事故数据的列名和空值
print("Traffic data columns:", traffic_df.columns)
print("Missing values in traffic data:\n", traffic_df.isnull().sum())
# Out:
# Traffic data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', '201801_rate', '201802_rate',
#        '201803_rate', '201804_rate', '201805_rate', '201806_rate',
#        '201807_rate', '201808_rate', '201809_rate', '201810_rate',
#        '201811_rate', '201812_rate', '201901_rate', '201902_rate',
#        '201903_rate', '201904_rate', '201905_rate', '201906_rate',
#        '201907_rate', '201908_rate', '201909_rate', '201910_rate',
#        '201911_rate', '201912_rate', '202001_rate', '202002_rate',
#        '202003_rate', '202004_rate', '202005_rate', '202006_rate',
#        '202007_rate', '202008_rate', '202009_rate', '202010_rate',
#        '202011_rate', '202012_rate', '202101_rate', '202102_rate',
#        '202103_rate', '202104_rate', '202105_rate', '202106_rate',
#        '202107_rate', '202108_rate', '202109_rate', '202110_rate',
#        '202111_rate', '202112_rate', '202201_rate', '202202_rate',
#        '202203_rate', '202204_rate', '202205_rate', '202206_rate',
#        '202207_rate', '202208_rate', '202209_rate', '202210_rate',
#        '202211_rate', '202212_rate'],
#       dtype='object')
# Missing values in traffic data:
#  COD_DIS        0
# COD_BAR        0
# NOMBRE_BAR     0
# 201801_rate    0
# 201802_rate    0
#               ..
# 202208_rate    0
# 202209_rate    0
# 202210_rate    0
# 202211_rate    0
# 202212_rate    0
# Length: 63, dtype: int64

# %%
control_data_file = 'CONTROL_ADD_PAND.xlsx'  # 根据实际路径修改
education_df = pd.read_excel(control_data_file, sheet_name='EDUCATION')
income_df = pd.read_excel(control_data_file, sheet_name='INCOME')
population_df = pd.read_excel(control_data_file, sheet_name='POPULATION')
transport_df = pd.read_excel(control_data_file, sheet_name='TRANSPORT')
commercial_df = pd.read_excel(control_data_file, sheet_name='COMMERCIAL')
residential_df = pd.read_excel(control_data_file, sheet_name='RESIDENTIAL')
PAND_df = pd.read_excel(control_data_file, sheet_name='PANDEMIC')


# 检查每个社会因子数据的列名和空值情况
dataframes = {
    "EDUCATION": education_df,
    "INCOME": income_df,
    "POPULATION": population_df,
    "TRANSPORT": transport_df,
    "COMMERCIAL": commercial_df,
    "RESIDENTIAL": residential_df,
    "PANDEMIC": PAND_df
}

# 打印每个工作表的列名和空值数量
for sheet_name, df in dataframes.items():
    print(f"\n{sheet_name} data columns:", df.columns)
    print(f"Missing values in {sheet_name} data:\n", df.isnull().sum())
# Out:
# EDUCATION data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'EDUCATION_2018_01',
#        'EDUCATION_2018_02', 'EDUCATION_2018_03', 'EDUCATION_2018_04',
#        'EDUCATION_2018_05', 'EDUCATION_2018_06', 'EDUCATION_2018_07',
#        'EDUCATION_2018_08', 'EDUCATION_2018_09', 'EDUCATION_2018_10',
#        'EDUCATION_2018_11', 'EDUCATION_2018_12', 'EDUCATION_2019_01',
#        'EDUCATION_2019_02', 'EDUCATION_2019_03', 'EDUCATION_2019_04',
#        'EDUCATION_2019_05', 'EDUCATION_2019_06', 'EDUCATION_2019_07',
#        'EDUCATION_2019_08', 'EDUCATION_2019_09', 'EDUCATION_2019_10',
#        'EDUCATION_2019_11', 'EDUCATION_2019_12', 'EDUCATION_2020_01',
#        'EDUCATION_2020_02', 'EDUCATION_2020_03', 'EDUCATION_2020_04',
#        'EDUCATION_2020_05', 'EDUCATION_2020_06', 'EDUCATION_2020_07',
#        'EDUCATION_2020_08', 'EDUCATION_2020_09', 'EDUCATION_2020_10',
#        'EDUCATION_2020_11', 'EDUCATION_2020_12', 'EDUCATION_2021_01',
#        'EDUCATION_2021_02', 'EDUCATION_2021_03', 'EDUCATION_2021_04',
#        'EDUCATION_2021_05', 'EDUCATION_2021_06', 'EDUCATION_2021_07',
#        'EDUCATION_2021_08', 'EDUCATION_2021_09', 'EDUCATION_2021_10',
#        'EDUCATION_2021_11', 'EDUCATION_2021_12', 'EDUCATION_2022_01',
#        'EDUCATION_2022_02', 'EDUCATION_2022_03', 'EDUCATION_2022_04',
#        'EDUCATION_2022_05', 'EDUCATION_2022_06', 'EDUCATION_2022_07',
#        'EDUCATION_2022_08', 'EDUCATION_2022_09', 'EDUCATION_2022_10',
#        'EDUCATION_2022_11', 'EDUCATION_2022_12'],
#       dtype='object')
# Missing values in EDUCATION data:
#  COD_DIS              0
# COD_BAR              0
# NOMBRE_BAR           0
# EDUCATION_2018_01    0
# EDUCATION_2018_02    0
#                     ..
# EDUCATION_2022_08    0
# EDUCATION_2022_09    0
# EDUCATION_2022_10    0
# EDUCATION_2022_11    0
# EDUCATION_2022_12    0
# Length: 63, dtype: int64
#
# INCOME data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'INCOME_2018_01', 'INCOME_2018_02',
#        'INCOME_2018_03', 'INCOME_2018_04', 'INCOME_2018_05', 'INCOME_2018_06',
#        'INCOME_2018_07', 'INCOME_2018_08', 'INCOME_2018_09', 'INCOME_2018_10',
#        'INCOME_2018_11', 'INCOME_2018_12', 'INCOME_2019_01', 'INCOME_2019_02',
#        'INCOME_2019_03', 'INCOME_2019_04', 'INCOME_2019_05', 'INCOME_2019_06',
#        'INCOME_2019_07', 'INCOME_2019_08', 'INCOME_2019_09', 'INCOME_2019_10',
#        'INCOME_2019_11', 'INCOME_2019_12', 'INCOME_2020_01', 'INCOME_2020_02',
#        'INCOME_2020_03', 'INCOME_2020_04', 'INCOME_2020_05', 'INCOME_2020_06',
#        'INCOME_2020_07', 'INCOME_2020_08', 'INCOME_2020_09', 'INCOME_2020_10',
#        'INCOME_2020_11', 'INCOME_2020_12', 'INCOME_2021_01', 'INCOME_2021_02',
#        'INCOME_2021_03', 'INCOME_2021_04', 'INCOME_2021_05', 'INCOME_2021_06',
#        'INCOME_2021_07', 'INCOME_2021_08', 'INCOME_2021_09', 'INCOME_2021_10',
#        'INCOME_2021_11', 'INCOME_2021_12', 'INCOME_2022_01', 'INCOME_2022_02',
#        'INCOME_2022_03', 'INCOME_2022_04', 'INCOME_2022_05', 'INCOME_2022_06',
#        'INCOME_2022_07', 'INCOME_2022_08', 'INCOME_2022_09', 'INCOME_2022_10',
#        'INCOME_2022_11', 'INCOME_2022_12'],
#       dtype='object')
# Missing values in INCOME data:
#  COD_DIS           0
# COD_BAR           0
# NOMBRE_BAR        0
# INCOME_2018_01    0
# INCOME_2018_02    0
#                  ..
# INCOME_2022_08    0
# INCOME_2022_09    0
# INCOME_2022_10    0
# INCOME_2022_11    0
# INCOME_2022_12    0
# Length: 63, dtype: int64
#
# POPULATION data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'POPULATION_2018_01',
#        'POPULATION_2018_02', 'POPULATION_2018_03', 'POPULATION_2018_04',
#        'POPULATION_2018_05', 'POPULATION_2018_06', 'POPULATION_2018_07',
#        'POPULATION_2018_08', 'POPULATION_2018_09', 'POPULATION_2018_10',
#        'POPULATION_2018_11', 'POPULATION_2018_12', 'POPULATION_2019_01',
#        'POPULATION_2019_02', 'POPULATION_2019_03', 'POPULATION_2019_04',
#        'POPULATION_2019_05', 'POPULATION_2019_06', 'POPULATION_2019_07',
#        'POPULATION_2019_08', 'POPULATION_2019_09', 'POPULATION_2019_10',
#        'POPULATION_2019_11', 'POPULATION_2019_12', 'POPULATION_2020_01',
#        'POPULATION_2020_02', 'POPULATION_2020_03', 'POPULATION_2020_04',
#        'POPULATION_2020_05', 'POPULATION_2020_06', 'POPULATION_2020_07',
#        'POPULATION_2020_08', 'POPULATION_2020_09', 'POPULATION_2020_10',
#        'POPULATION_2020_11', 'POPULATION_2020_12', 'POPULATION_2021_01',
#        'POPULATION_2021_02', 'POPULATION_2021_03', 'POPULATION_2021_04',
#        'POPULATION_2021_05', 'POPULATION_2021_06', 'POPULATION_2021_07',
#        'POPULATION_2021_08', 'POPULATION_2021_09', 'POPULATION_2021_10',
#        'POPULATION_2021_11', 'POPULATION_2021_12', 'POPULATION_2022_01',
#        'POPULATION_2022_02', 'POPULATION_2022_03', 'POPULATION_2022_04',
#        'POPULATION_2022_05', 'POPULATION_2022_06', 'POPULATION_2022_07',
#        'POPULATION_2022_08', 'POPULATION_2022_09', 'POPULATION_2022_10',
#        'POPULATION_2022_11', 'POPULATION_2022_12'],
#       dtype='object')
# Missing values in POPULATION data:
#  COD_DIS               0
# COD_BAR               0
# NOMBRE_BAR            0
# POPULATION_2018_01    0
# POPULATION_2018_02    0
#                      ..
# POPULATION_2022_08    0
# POPULATION_2022_09    0
# POPULATION_2022_10    0
# POPULATION_2022_11    0
# POPULATION_2022_12    0
# Length: 63, dtype: int64
#
# TRANSPORT data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'TRANSPORT_2018_01',
#        'TRANSPORT_2018_02', 'TRANSPORT_2018_03', 'TRANSPORT_2018_04',
#        'TRANSPORT_2018_05', 'TRANSPORT_2018_06', 'TRANSPORT_2018_07',
#        'TRANSPORT_2018_08', 'TRANSPORT_2018_09', 'TRANSPORT_2018_10',
#        'TRANSPORT_2018_11', 'TRANSPORT_2018_12', 'TRANSPORT_2019_01',
#        'TRANSPORT_2019_02', 'TRANSPORT_2019_03', 'TRANSPORT_2019_04',
#        'TRANSPORT_2019_05', 'TRANSPORT_2019_06', 'TRANSPORT_2019_07',
#        'TRANSPORT_2019_08', 'TRANSPORT_2019_09', 'TRANSPORT_2019_10',
#        'TRANSPORT_2019_11', 'TRANSPORT_2019_12', 'TRANSPORT_2020_01',
#        'TRANSPORT_2020_02', 'TRANSPORT_2020_03', 'TRANSPORT_2020_04',
#        'TRANSPORT_2020_05', 'TRANSPORT_2020_06', 'TRANSPORT_2020_07',
#        'TRANSPORT_2020_08', 'TRANSPORT_2020_09', 'TRANSPORT_2020_10',
#        'TRANSPORT_2020_11', 'TRANSPORT_2020_12', 'TRANSPORT_2021_01',
#        'TRANSPORT_2021_02', 'TRANSPORT_2021_03', 'TRANSPORT_2021_04',
#        'TRANSPORT_2021_05', 'TRANSPORT_2021_06', 'TRANSPORT_2021_07',
#        'TRANSPORT_2021_08', 'TRANSPORT_2021_09', 'TRANSPORT_2021_10',
#        'TRANSPORT_2021_11', 'TRANSPORT_2021_12', 'TRANSPORT_2022_01',
#        'TRANSPORT_2022_02', 'TRANSPORT_2022_03', 'TRANSPORT_2022_04',
#        'TRANSPORT_2022_05', 'TRANSPORT_2022_06', 'TRANSPORT_2022_07',
#        'TRANSPORT_2022_08', 'TRANSPORT_2022_09', 'TRANSPORT_2022_10',
#        'TRANSPORT_2022_11', 'TRANSPORT_2022_12'],
#       dtype='object')
# Missing values in TRANSPORT data:
#  COD_DIS              0
# COD_BAR              0
# NOMBRE_BAR           0
# TRANSPORT_2018_01    0
# TRANSPORT_2018_02    0
#                     ..
# TRANSPORT_2022_08    0
# TRANSPORT_2022_09    0
# TRANSPORT_2022_10    0
# TRANSPORT_2022_11    0
# TRANSPORT_2022_12    0
# Length: 63, dtype: int64
#
# COMMERCIAL data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'COMMERCIAL_2018_01',
#        'COMMERCIAL_2018_02', 'COMMERCIAL_2018_03', 'COMMERCIAL_2018_04',
#        'COMMERCIAL_2018_05', 'COMMERCIAL_2018_06', 'COMMERCIAL_2018_07',
#        'COMMERCIAL_2018_08', 'COMMERCIAL_2018_09', 'COMMERCIAL_2018_10',
#        'COMMERCIAL_2018_11', 'COMMERCIAL_2018_12', 'COMMERCIAL_2019_01',
#        'COMMERCIAL_2019_02', 'COMMERCIAL_2019_03', 'COMMERCIAL_2019_04',
#        'COMMERCIAL_2019_05', 'COMMERCIAL_2019_06', 'COMMERCIAL_2019_07',
#        'COMMERCIAL_2019_08', 'COMMERCIAL_2019_09', 'COMMERCIAL_2019_10',
#        'COMMERCIAL_2019_11', 'COMMERCIAL_2019_12', 'COMMERCIAL_2020_01',
#        'COMMERCIAL_2020_02', 'COMMERCIAL_2020_03', 'COMMERCIAL_2020_04',
#        'COMMERCIAL_2020_05', 'COMMERCIAL_2020_06', 'COMMERCIAL_2020_07',
#        'COMMERCIAL_2020_08', 'COMMERCIAL_2020_09', 'COMMERCIAL_2020_10',
#        'COMMERCIAL_2020_11', 'COMMERCIAL_2020_12', 'COMMERCIAL_2021_01',
#        'COMMERCIAL_2021_02', 'COMMERCIAL_2021_03', 'COMMERCIAL_2021_04',
#        'COMMERCIAL_2021_05', 'COMMERCIAL_2021_06', 'COMMERCIAL_2021_07',
#        'COMMERCIAL_2021_08', 'COMMERCIAL_2021_09', 'COMMERCIAL_2021_10',
#        'COMMERCIAL_2021_11', 'COMMERCIAL_2021_12', 'COMMERCIAL_2022_01',
#        'COMMERCIAL_2022_02', 'COMMERCIAL_2022_03', 'COMMERCIAL_2022_04',
#        'COMMERCIAL_2022_05', 'COMMERCIAL_2022_06', 'COMMERCIAL_2022_07',
#        'COMMERCIAL_2022_08', 'COMMERCIAL_2022_09', 'COMMERCIAL_2022_10',
#        'COMMERCIAL_2022_11', 'COMMERCIAL_2022_12'],
#       dtype='object')
# Missing values in COMMERCIAL data:
#  COD_DIS               0
# COD_BAR               0
# NOMBRE_BAR            0
# COMMERCIAL_2018_01    0
# COMMERCIAL_2018_02    0
#                      ..
# COMMERCIAL_2022_08    0
# COMMERCIAL_2022_09    0
# COMMERCIAL_2022_10    0
# COMMERCIAL_2022_11    0
# COMMERCIAL_2022_12    0
# Length: 63, dtype: int64
#
# RESIDENTIAL data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'RESIDENTIAL_2018_01',
#        'RESIDENTIAL_2018_02', 'RESIDENTIAL_2018_03', 'RESIDENTIAL_2018_04',
#        'RESIDENTIAL_2018_05', 'RESIDENTIAL_2018_06', 'RESIDENTIAL_2018_07',
#        'RESIDENTIAL_2018_08', 'RESIDENTIAL_2018_09', 'RESIDENTIAL_2018_10',
#        'RESIDENTIAL_2018_11', 'RESIDENTIAL_2018_12', 'RESIDENTIAL_2019_01',
#        'RESIDENTIAL_2019_02', 'RESIDENTIAL_2019_03', 'RESIDENTIAL_2019_04',
#        'RESIDENTIAL_2019_05', 'RESIDENTIAL_2019_06', 'RESIDENTIAL_2019_07',
#        'RESIDENTIAL_2019_08', 'RESIDENTIAL_2019_09', 'RESIDENTIAL_2019_10',
#        'RESIDENTIAL_2019_11', 'RESIDENTIAL_2019_12', 'RESIDENTIAL_2020_01',
#        'RESIDENTIAL_2020_02', 'RESIDENTIAL_2020_03', 'RESIDENTIAL_2020_04',
#        'RESIDENTIAL_2020_05', 'RESIDENTIAL_2020_06', 'RESIDENTIAL_2020_07',
#        'RESIDENTIAL_2020_08', 'RESIDENTIAL_2020_09', 'RESIDENTIAL_2020_10',
#        'RESIDENTIAL_2020_11', 'RESIDENTIAL_2020_12', 'RESIDENTIAL_2021_01',
#        'RESIDENTIAL_2021_02', 'RESIDENTIAL_2021_03', 'RESIDENTIAL_2021_04',
#        'RESIDENTIAL_2021_05', 'RESIDENTIAL_2021_06', 'RESIDENTIAL_2021_07',
#        'RESIDENTIAL_2021_08', 'RESIDENTIAL_2021_09', 'RESIDENTIAL_2021_10',
#        'RESIDENTIAL_2021_11', 'RESIDENTIAL_2021_12', 'RESIDENTIAL_2022_01',
#        'RESIDENTIAL_2022_02', 'RESIDENTIAL_2022_03', 'RESIDENTIAL_2022_04',
#        'RESIDENTIAL_2022_05', 'RESIDENTIAL_2022_06', 'RESIDENTIAL_2022_07',
#        'RESIDENTIAL_2022_08', 'RESIDENTIAL_2022_09', 'RESIDENTIAL_2022_10',
#        'RESIDENTIAL_2022_11', 'RESIDENTIAL_2022_12'],
#       dtype='object')
# Missing values in RESIDENTIAL data:
#  COD_DIS                0
# COD_BAR                0
# NOMBRE_BAR             0
# RESIDENTIAL_2018_01    0
# RESIDENTIAL_2018_02    0
#                       ..
# RESIDENTIAL_2022_08    0
# RESIDENTIAL_2022_09    0
# RESIDENTIAL_2022_10    0
# RESIDENTIAL_2022_11    0
# RESIDENTIAL_2022_12    0
# Length: 63, dtype: int64
#
# PANDEMIC data columns: Index(['COD_DIS', 'COD_BAR', 'PANDEMIC_2018_01', 'PANDEMIC_2018_02',
#        'PANDEMIC_2018_03', 'PANDEMIC_2018_04', 'PANDEMIC_2018_05',
#        'PANDEMIC_2018_06', 'PANDEMIC_2018_07', 'PANDEMIC_2018_08',
#        'PANDEMIC_2018_09', 'PANDEMIC_2018_10', 'PANDEMIC_2018_11',
#        'PANDEMIC_2018_12', 'PANDEMIC_2019_01', 'PANDEMIC_2019_02',
#        'PANDEMIC_2019_03', 'PANDEMIC_2019_04', 'PANDEMIC_2019_05',
#        'PANDEMIC_2019_06', 'PANDEMIC_2019_07', 'PANDEMIC_2019_08',
#        'PANDEMIC_2019_09', 'PANDEMIC_2019_10', 'PANDEMIC_2019_11',
#        'PANDEMIC_2019_12', 'PANDEMIC_2020_01', 'PANDEMIC_2020_02',
#        'PANDEMIC_2020_03', 'PANDEMIC_2020_04', 'PANDEMIC_2020_05',
#        'PANDEMIC_2020_06', 'PANDEMIC_2020_07', 'PANDEMIC_2020_08',
#        'PANDEMIC_2020_09', 'PANDEMIC_2020_10', 'PANDEMIC_2020_11',
#        'PANDEMIC_2020_12', 'PANDEMIC_2021_01', 'PANDEMIC_2021_02',
#        'PANDEMIC_2021_03', 'PANDEMIC_2021_04', 'PANDEMIC_2021_05',
#        'PANDEMIC_2021_06', 'PANDEMIC_2021_07', 'PANDEMIC_2021_08',
#        'PANDEMIC_2021_09', 'PANDEMIC_2021_10', 'PANDEMIC_2021_11',
#        'PANDEMIC_2021_12', 'PANDEMIC_2022_01', 'PANDEMIC_2022_02',
#        'PANDEMIC_2022_03', 'PANDEMIC_2022_04', 'PANDEMIC_2022_05',
#        'PANDEMIC_2022_06', 'PANDEMIC_2022_07', 'PANDEMIC_2022_08',
#        'PANDEMIC_2022_09', 'PANDEMIC_2022_10', 'PANDEMIC_2022_11',
#        'PANDEMIC_2022_12'],
#       dtype='object')
# Missing values in PANDEMIC data:
#  COD_DIS             0
# COD_BAR             0
# PANDEMIC_2018_01    0
# PANDEMIC_2018_02    0
# PANDEMIC_2018_03    0
#                    ..
# PANDEMIC_2022_08    0
# PANDEMIC_2022_09    0
# PANDEMIC_2022_10    0
# PANDEMIC_2022_11    0
# PANDEMIC_2022_12    0
# Length: 62, dtype: int64

# %%
# 读取政策处理信息
did_data_file = 'did_input_data_monthly.xlsx'  # 根据实际路径修改
did_df = pd.read_excel(did_data_file)

# 检查政策数据的列名和空值
print("Did data columns:", did_df.columns)
print("Missing values in did data:\n", did_df.isnull().sum())
# Out:
# Did data columns: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', 'year', 'month', 'treati', 'postit',
#        'treat*postit', 'DID'],
#       dtype='object')
# Missing values in did data:
#  COD_DIS         0
# COD_BAR         0
# NOMBRE_BAR      0
# year            0
# month           0
# treati          0
# postit          0
# treat*postit    0
# DID             0
# dtype: int64

# %%
# 打印列名，检查数据列
print("Columns in traffic_df before melt:", traffic_df.columns)

# 确保在melt时将所有以 '201801_rate' 格式命名的列都转换为 Date 和 accident_rate
traffic_df = traffic_df.melt(id_vars=['COD_DIS', 'COD_BAR'], 
                             value_vars=[col for col in traffic_df.columns if '_rate' in col],  # 选择包含 '_rate' 的列
                             var_name='Date', value_name='accident_rate_melted')

# 检查melt后的数据
print("Traffic Data after melt:")
print(traffic_df.head())

# 将 'YYYYMM_rate' 转化为 'YYYY-MM' 格式的日期
traffic_df['Date'] = traffic_df['Date'].str[:4] + '-' + traffic_df['Date'].str[4:6]

# 检查转换后的日期格式
print("Traffic Data after date conversion:")
print(traffic_df.head())
# Out:
# Columns in traffic_df before melt: Index(['COD_DIS', 'COD_BAR', 'NOMBRE_BAR', '201801_rate', '201802_rate',
#        '201803_rate', '201804_rate', '201805_rate', '201806_rate',
#        '201807_rate', '201808_rate', '201809_rate', '201810_rate',
#        '201811_rate', '201812_rate', '201901_rate', '201902_rate',
#        '201903_rate', '201904_rate', '201905_rate', '201906_rate',
#        '201907_rate', '201908_rate', '201909_rate', '201910_rate',
#        '201911_rate', '201912_rate', '202001_rate', '202002_rate',
#        '202003_rate', '202004_rate', '202005_rate', '202006_rate',
#        '202007_rate', '202008_rate', '202009_rate', '202010_rate',
#        '202011_rate', '202012_rate', '202101_rate', '202102_rate',
#        '202103_rate', '202104_rate', '202105_rate', '202106_rate',
#        '202107_rate', '202108_rate', '202109_rate', '202110_rate',
#        '202111_rate', '202112_rate', '202201_rate', '202202_rate',
#        '202203_rate', '202204_rate', '202205_rate', '202206_rate',
#        '202207_rate', '202208_rate', '202209_rate', '202210_rate',
#        '202211_rate', '202212_rate'],
#       dtype='object')
# Traffic Data after melt:
#    COD_DIS  COD_BAR         Date  accident_rate_melted
# 0        1       11  201801_rate                 13.05
# 1        1       12  201801_rate                  6.82
# 2        1       13  201801_rate                 25.65
# 3        1       14  201801_rate                 25.57
# 4        1       15  201801_rate                 16.03
# Traffic Data after date conversion:
#    COD_DIS  COD_BAR     Date  accident_rate_melted
# 0        1       11  2018-01                 13.05
# 1        1       12  2018-01                  6.82
# 2        1       13  2018-01                 25.65
# 3        1       14  2018-01                 25.57
# 4        1       15  2018-01                 16.03

# %%
def merge_social_factors(df, social_factor_df, factor_name):
    # 检查传入的 df 是否为 None
    if df is None:
        raise ValueError("The main DataFrame 'df' cannot be None")
    
    # 找出所有包含日期信息的列（假设列名格式为 '因子名称_YYYY_MM'）
    date_columns = [col for col in social_factor_df.columns if '_' in col and len(col.split('_')) == 3]  # 查找列名中包含'_'并且长度为3的列
    
    # 打印调试信息，查看哪些列符合预期格式
    print(f"Date columns in {factor_name} data:", date_columns)
    
    # 创建一个空的 DataFrame 用于存储处理后的数据
    melted_df = pd.DataFrame()
    
    # 遍历所有列
    for col in date_columns:
        # 提取列名中的因子名称和日期部分
        factor, date_str = col.split('_')[0], col.split('_')[1] + '-' + col.split('_')[2]
        
        # 生成一个新的 DataFrame，包含 'COD_DIS', 'COD_BAR', 'Date', 和因子值
        temp_df = social_factor_df[['COD_DIS', 'COD_BAR', col]].copy()
        temp_df['Date'] = date_str  # 添加日期列
        temp_df.rename(columns={col: factor_name}, inplace=True)  # 重命名因子值列
        
        # 将这个 DataFrame 合并到结果中
        melted_df = pd.concat([melted_df, temp_df], ignore_index=True)

    # 检查社会因子数据是否有缺失值
    print(f"Missing values in {factor_name} data:\n", melted_df.isnull().sum())
    
    # 确保合并时列一致
    print(f"Columns in df before merge: {df.columns}")
    print(f"Columns in melted_df before merge: {melted_df.columns}")
    
    # 合并到主数据集
    df = pd.merge(df, melted_df, on=['COD_DIS', 'COD_BAR',  'Date'], how='left')
    
    print(f"Columns in df after merge: {df.columns}")  # 打印合并后的列名
    
    return df

# 确保 traffic_df 是有效的 DataFrame
if traffic_df is None:
    print("Error: traffic_df is None")
else:
    traffic_df = merge_social_factors(traffic_df, education_df, 'EDUCATION')
    traffic_df = merge_social_factors(traffic_df, income_df, 'INCOME')
    traffic_df = merge_social_factors(traffic_df, population_df, 'POPULATION')
    traffic_df = merge_social_factors(traffic_df, transport_df, 'TRANSPORT')
    traffic_df = merge_social_factors(traffic_df, commercial_df, 'COMMERCIAL')
    traffic_df = merge_social_factors(traffic_df, residential_df, 'RESIDENTIAL')
    traffic_df = merge_social_factors(traffic_df, PAND_df, 'PANDEMIC')
# Out:
# Date columns in EDUCATION data: ['EDUCATION_2018_01', 'EDUCATION_2018_02', 'EDUCATION_2018_03', 'EDUCATION_2018_04', 'EDUCATION_2018_05', 'EDUCATION_2018_06', 'EDUCATION_2018_07', 'EDUCATION_2018_08', 'EDUCATION_2018_09', 'EDUCATION_2018_10', 'EDUCATION_2018_11', 'EDUCATION_2018_12', 'EDUCATION_2019_01', 'EDUCATION_2019_02', 'EDUCATION_2019_03', 'EDUCATION_2019_04', 'EDUCATION_2019_05', 'EDUCATION_2019_06', 'EDUCATION_2019_07', 'EDUCATION_2019_08', 'EDUCATION_2019_09', 'EDUCATION_2019_10', 'EDUCATION_2019_11', 'EDUCATION_2019_12', 'EDUCATION_2020_01', 'EDUCATION_2020_02', 'EDUCATION_2020_03', 'EDUCATION_2020_04', 'EDUCATION_2020_05', 'EDUCATION_2020_06', 'EDUCATION_2020_07', 'EDUCATION_2020_08', 'EDUCATION_2020_09', 'EDUCATION_2020_10', 'EDUCATION_2020_11', 'EDUCATION_2020_12', 'EDUCATION_2021_01', 'EDUCATION_2021_02', 'EDUCATION_2021_03', 'EDUCATION_2021_04', 'EDUCATION_2021_05', 'EDUCATION_2021_06', 'EDUCATION_2021_07', 'EDUCATION_2021_08', 'EDUCATION_2021_09', 'EDUCATION_2021_10', 'EDUCATION_2021_11', 'EDUCATION_2021_12', 'EDUCATION_2022_01', 'EDUCATION_2022_02', 'EDUCATION_2022_03', 'EDUCATION_2022_04', 'EDUCATION_2022_05', 'EDUCATION_2022_06', 'EDUCATION_2022_07', 'EDUCATION_2022_08', 'EDUCATION_2022_09', 'EDUCATION_2022_10', 'EDUCATION_2022_11', 'EDUCATION_2022_12']
# Missing values in EDUCATION data:
#  COD_DIS      0
# COD_BAR      0
# EDUCATION    0
# Date         0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted'], dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'EDUCATION', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION'], dtype='object')
# Date columns in INCOME data: ['INCOME_2018_01', 'INCOME_2018_02', 'INCOME_2018_03', 'INCOME_2018_04', 'INCOME_2018_05', 'INCOME_2018_06', 'INCOME_2018_07', 'INCOME_2018_08', 'INCOME_2018_09', 'INCOME_2018_10', 'INCOME_2018_11', 'INCOME_2018_12', 'INCOME_2019_01', 'INCOME_2019_02', 'INCOME_2019_03', 'INCOME_2019_04', 'INCOME_2019_05', 'INCOME_2019_06', 'INCOME_2019_07', 'INCOME_2019_08', 'INCOME_2019_09', 'INCOME_2019_10', 'INCOME_2019_11', 'INCOME_2019_12', 'INCOME_2020_01', 'INCOME_2020_02', 'INCOME_2020_03', 'INCOME_2020_04', 'INCOME_2020_05', 'INCOME_2020_06', 'INCOME_2020_07', 'INCOME_2020_08', 'INCOME_2020_09', 'INCOME_2020_10', 'INCOME_2020_11', 'INCOME_2020_12', 'INCOME_2021_01', 'INCOME_2021_02', 'INCOME_2021_03', 'INCOME_2021_04', 'INCOME_2021_05', 'INCOME_2021_06', 'INCOME_2021_07', 'INCOME_2021_08', 'INCOME_2021_09', 'INCOME_2021_10', 'INCOME_2021_11', 'INCOME_2021_12', 'INCOME_2022_01', 'INCOME_2022_02', 'INCOME_2022_03', 'INCOME_2022_04', 'INCOME_2022_05', 'INCOME_2022_06', 'INCOME_2022_07', 'INCOME_2022_08', 'INCOME_2022_09', 'INCOME_2022_10', 'INCOME_2022_11', 'INCOME_2022_12']
# Missing values in INCOME data:
#  COD_DIS    0
# COD_BAR    0
# INCOME     0
# Date       0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION'], dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'INCOME', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME'],
#       dtype='object')
# Date columns in POPULATION data: ['POPULATION_2018_01', 'POPULATION_2018_02', 'POPULATION_2018_03', 'POPULATION_2018_04', 'POPULATION_2018_05', 'POPULATION_2018_06', 'POPULATION_2018_07', 'POPULATION_2018_08', 'POPULATION_2018_09', 'POPULATION_2018_10', 'POPULATION_2018_11', 'POPULATION_2018_12', 'POPULATION_2019_01', 'POPULATION_2019_02', 'POPULATION_2019_03', 'POPULATION_2019_04', 'POPULATION_2019_05', 'POPULATION_2019_06', 'POPULATION_2019_07', 'POPULATION_2019_08', 'POPULATION_2019_09', 'POPULATION_2019_10', 'POPULATION_2019_11', 'POPULATION_2019_12', 'POPULATION_2020_01', 'POPULATION_2020_02', 'POPULATION_2020_03', 'POPULATION_2020_04', 'POPULATION_2020_05', 'POPULATION_2020_06', 'POPULATION_2020_07', 'POPULATION_2020_08', 'POPULATION_2020_09', 'POPULATION_2020_10', 'POPULATION_2020_11', 'POPULATION_2020_12', 'POPULATION_2021_01', 'POPULATION_2021_02', 'POPULATION_2021_03', 'POPULATION_2021_04', 'POPULATION_2021_05', 'POPULATION_2021_06', 'POPULATION_2021_07', 'POPULATION_2021_08', 'POPULATION_2021_09', 'POPULATION_2021_10', 'POPULATION_2021_11', 'POPULATION_2021_12', 'POPULATION_2022_01', 'POPULATION_2022_02', 'POPULATION_2022_03', 'POPULATION_2022_04', 'POPULATION_2022_05', 'POPULATION_2022_06', 'POPULATION_2022_07', 'POPULATION_2022_08', 'POPULATION_2022_09', 'POPULATION_2022_10', 'POPULATION_2022_11', 'POPULATION_2022_12']
# Missing values in POPULATION data:
#  COD_DIS       0
# COD_BAR       0
# POPULATION    0
# Date          0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME'],
#       dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'POPULATION', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION'],
#       dtype='object')
# Date columns in TRANSPORT data: ['TRANSPORT_2018_01', 'TRANSPORT_2018_02', 'TRANSPORT_2018_03', 'TRANSPORT_2018_04', 'TRANSPORT_2018_05', 'TRANSPORT_2018_06', 'TRANSPORT_2018_07', 'TRANSPORT_2018_08', 'TRANSPORT_2018_09', 'TRANSPORT_2018_10', 'TRANSPORT_2018_11', 'TRANSPORT_2018_12', 'TRANSPORT_2019_01', 'TRANSPORT_2019_02', 'TRANSPORT_2019_03', 'TRANSPORT_2019_04', 'TRANSPORT_2019_05', 'TRANSPORT_2019_06', 'TRANSPORT_2019_07', 'TRANSPORT_2019_08', 'TRANSPORT_2019_09', 'TRANSPORT_2019_10', 'TRANSPORT_2019_11', 'TRANSPORT_2019_12', 'TRANSPORT_2020_01', 'TRANSPORT_2020_02', 'TRANSPORT_2020_03', 'TRANSPORT_2020_04', 'TRANSPORT_2020_05', 'TRANSPORT_2020_06', 'TRANSPORT_2020_07', 'TRANSPORT_2020_08', 'TRANSPORT_2020_09', 'TRANSPORT_2020_10', 'TRANSPORT_2020_11', 'TRANSPORT_2020_12', 'TRANSPORT_2021_01', 'TRANSPORT_2021_02', 'TRANSPORT_2021_03', 'TRANSPORT_2021_04', 'TRANSPORT_2021_05', 'TRANSPORT_2021_06', 'TRANSPORT_2021_07', 'TRANSPORT_2021_08', 'TRANSPORT_2021_09', 'TRANSPORT_2021_10', 'TRANSPORT_2021_11', 'TRANSPORT_2021_12', 'TRANSPORT_2022_01', 'TRANSPORT_2022_02', 'TRANSPORT_2022_03', 'TRANSPORT_2022_04', 'TRANSPORT_2022_05', 'TRANSPORT_2022_06', 'TRANSPORT_2022_07', 'TRANSPORT_2022_08', 'TRANSPORT_2022_09', 'TRANSPORT_2022_10', 'TRANSPORT_2022_11', 'TRANSPORT_2022_12']
# Missing values in TRANSPORT data:
#  COD_DIS      0
# COD_BAR      0
# TRANSPORT    0
# Date         0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION'],
#       dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'TRANSPORT', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT'],
#       dtype='object')
# Date columns in COMMERCIAL data: ['COMMERCIAL_2018_01', 'COMMERCIAL_2018_02', 'COMMERCIAL_2018_03', 'COMMERCIAL_2018_04', 'COMMERCIAL_2018_05', 'COMMERCIAL_2018_06', 'COMMERCIAL_2018_07', 'COMMERCIAL_2018_08', 'COMMERCIAL_2018_09', 'COMMERCIAL_2018_10', 'COMMERCIAL_2018_11', 'COMMERCIAL_2018_12', 'COMMERCIAL_2019_01', 'COMMERCIAL_2019_02', 'COMMERCIAL_2019_03', 'COMMERCIAL_2019_04', 'COMMERCIAL_2019_05', 'COMMERCIAL_2019_06', 'COMMERCIAL_2019_07', 'COMMERCIAL_2019_08', 'COMMERCIAL_2019_09', 'COMMERCIAL_2019_10', 'COMMERCIAL_2019_11', 'COMMERCIAL_2019_12', 'COMMERCIAL_2020_01', 'COMMERCIAL_2020_02', 'COMMERCIAL_2020_03', 'COMMERCIAL_2020_04', 'COMMERCIAL_2020_05', 'COMMERCIAL_2020_06', 'COMMERCIAL_2020_07', 'COMMERCIAL_2020_08', 'COMMERCIAL_2020_09', 'COMMERCIAL_2020_10', 'COMMERCIAL_2020_11', 'COMMERCIAL_2020_12', 'COMMERCIAL_2021_01', 'COMMERCIAL_2021_02', 'COMMERCIAL_2021_03', 'COMMERCIAL_2021_04', 'COMMERCIAL_2021_05', 'COMMERCIAL_2021_06', 'COMMERCIAL_2021_07', 'COMMERCIAL_2021_08', 'COMMERCIAL_2021_09', 'COMMERCIAL_2021_10', 'COMMERCIAL_2021_11', 'COMMERCIAL_2021_12', 'COMMERCIAL_2022_01', 'COMMERCIAL_2022_02', 'COMMERCIAL_2022_03', 'COMMERCIAL_2022_04', 'COMMERCIAL_2022_05', 'COMMERCIAL_2022_06', 'COMMERCIAL_2022_07', 'COMMERCIAL_2022_08', 'COMMERCIAL_2022_09', 'COMMERCIAL_2022_10', 'COMMERCIAL_2022_11', 'COMMERCIAL_2022_12']
# Missing values in COMMERCIAL data:
#  COD_DIS       0
# COD_BAR       0
# COMMERCIAL    0
# Date          0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT'],
#       dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'COMMERCIAL', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT', 'COMMERCIAL'],
#       dtype='object')
# Date columns in RESIDENTIAL data: ['RESIDENTIAL_2018_01', 'RESIDENTIAL_2018_02', 'RESIDENTIAL_2018_03', 'RESIDENTIAL_2018_04', 'RESIDENTIAL_2018_05', 'RESIDENTIAL_2018_06', 'RESIDENTIAL_2018_07', 'RESIDENTIAL_2018_08', 'RESIDENTIAL_2018_09', 'RESIDENTIAL_2018_10', 'RESIDENTIAL_2018_11', 'RESIDENTIAL_2018_12', 'RESIDENTIAL_2019_01', 'RESIDENTIAL_2019_02', 'RESIDENTIAL_2019_03', 'RESIDENTIAL_2019_04', 'RESIDENTIAL_2019_05', 'RESIDENTIAL_2019_06', 'RESIDENTIAL_2019_07', 'RESIDENTIAL_2019_08', 'RESIDENTIAL_2019_09', 'RESIDENTIAL_2019_10', 'RESIDENTIAL_2019_11', 'RESIDENTIAL_2019_12', 'RESIDENTIAL_2020_01', 'RESIDENTIAL_2020_02', 'RESIDENTIAL_2020_03', 'RESIDENTIAL_2020_04', 'RESIDENTIAL_2020_05', 'RESIDENTIAL_2020_06', 'RESIDENTIAL_2020_07', 'RESIDENTIAL_2020_08', 'RESIDENTIAL_2020_09', 'RESIDENTIAL_2020_10', 'RESIDENTIAL_2020_11', 'RESIDENTIAL_2020_12', 'RESIDENTIAL_2021_01', 'RESIDENTIAL_2021_02', 'RESIDENTIAL_2021_03', 'RESIDENTIAL_2021_04', 'RESIDENTIAL_2021_05', 'RESIDENTIAL_2021_06', 'RESIDENTIAL_2021_07', 'RESIDENTIAL_2021_08', 'RESIDENTIAL_2021_09', 'RESIDENTIAL_2021_10', 'RESIDENTIAL_2021_11', 'RESIDENTIAL_2021_12', 'RESIDENTIAL_2022_01', 'RESIDENTIAL_2022_02', 'RESIDENTIAL_2022_03', 'RESIDENTIAL_2022_04', 'RESIDENTIAL_2022_05', 'RESIDENTIAL_2022_06', 'RESIDENTIAL_2022_07', 'RESIDENTIAL_2022_08', 'RESIDENTIAL_2022_09', 'RESIDENTIAL_2022_10', 'RESIDENTIAL_2022_11', 'RESIDENTIAL_2022_12']
# Missing values in RESIDENTIAL data:
#  COD_DIS        0
# COD_BAR        0
# RESIDENTIAL    0
# Date           0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT', 'COMMERCIAL'],
#       dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'RESIDENTIAL', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT', 'COMMERCIAL', 'RESIDENTIAL'],
#       dtype='object')
# Date columns in PANDEMIC data: ['PANDEMIC_2018_01', 'PANDEMIC_2018_02', 'PANDEMIC_2018_03', 'PANDEMIC_2018_04', 'PANDEMIC_2018_05', 'PANDEMIC_2018_06', 'PANDEMIC_2018_07', 'PANDEMIC_2018_08', 'PANDEMIC_2018_09', 'PANDEMIC_2018_10', 'PANDEMIC_2018_11', 'PANDEMIC_2018_12', 'PANDEMIC_2019_01', 'PANDEMIC_2019_02', 'PANDEMIC_2019_03', 'PANDEMIC_2019_04', 'PANDEMIC_2019_05', 'PANDEMIC_2019_06', 'PANDEMIC_2019_07', 'PANDEMIC_2019_08', 'PANDEMIC_2019_09', 'PANDEMIC_2019_10', 'PANDEMIC_2019_11', 'PANDEMIC_2019_12', 'PANDEMIC_2020_01', 'PANDEMIC_2020_02', 'PANDEMIC_2020_03', 'PANDEMIC_2020_04', 'PANDEMIC_2020_05', 'PANDEMIC_2020_06', 'PANDEMIC_2020_07', 'PANDEMIC_2020_08', 'PANDEMIC_2020_09', 'PANDEMIC_2020_10', 'PANDEMIC_2020_11', 'PANDEMIC_2020_12', 'PANDEMIC_2021_01', 'PANDEMIC_2021_02', 'PANDEMIC_2021_03', 'PANDEMIC_2021_04', 'PANDEMIC_2021_05', 'PANDEMIC_2021_06', 'PANDEMIC_2021_07', 'PANDEMIC_2021_08', 'PANDEMIC_2021_09', 'PANDEMIC_2021_10', 'PANDEMIC_2021_11', 'PANDEMIC_2021_12', 'PANDEMIC_2022_01', 'PANDEMIC_2022_02', 'PANDEMIC_2022_03', 'PANDEMIC_2022_04', 'PANDEMIC_2022_05', 'PANDEMIC_2022_06', 'PANDEMIC_2022_07', 'PANDEMIC_2022_08', 'PANDEMIC_2022_09', 'PANDEMIC_2022_10', 'PANDEMIC_2022_11', 'PANDEMIC_2022_12']
# Missing values in PANDEMIC data:
#  COD_DIS     0
# COD_BAR     0
# PANDEMIC    0
# Date        0
# dtype: int64
# Columns in df before merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT', 'COMMERCIAL', 'RESIDENTIAL'],
#       dtype='object')
# Columns in melted_df before merge: Index(['COD_DIS', 'COD_BAR', 'PANDEMIC', 'Date'], dtype='object')
# Columns in df after merge: Index(['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted', 'EDUCATION',
#        'INCOME', 'POPULATION', 'TRANSPORT', 'COMMERCIAL', 'RESIDENTIAL',
#        'PANDEMIC'],
#       dtype='object')

# %%
# 对合并后的数据进行归一化
def normalize_social_factors(df):
    # 找出所有需要归一化的列（不包括 'COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted'）
    factor_columns = [col for col in df.columns if col not in ['COD_DIS', 'COD_BAR', 'Date', 'accident_rate_melted','PANDEMIC']]
    
    # 对每一列进行归一化
    for col in factor_columns:
        min_val = df[col].min()
        max_val = df[col].max()
        df[col] = (df[col] - min_val) / (max_val - min_val)
        
    return df

# 执行归一化操作并直接替换原数据
traffic_df = normalize_social_factors(traffic_df)

# 打印归一化后的数据
print(traffic_df.head())
# Out:
#    COD_DIS  COD_BAR     Date  accident_rate_melted  EDUCATION    INCOME  \
# 0        1       11  2018-01                 13.05   0.734139  0.372007
# 1        1       12  2018-01                  6.82   0.605152  0.372007
# 2        1       13  2018-01                 25.65   0.801392  0.372007
# 3        1       14  2018-01                 25.57   0.820755  0.372007
# 4        1       15  2018-01                 16.03   0.748281  0.372007
#
#    POPULATION  TRANSPORT  COMMERCIAL  RESIDENTIAL  PANDEMIC
# 0    0.337342   0.464719    0.249695     0.317589         0
# 1    0.948914   0.448354    0.284157     0.808627         0
# 2    0.383697   0.784132    0.413408     0.648305         0
# 3    0.502189   0.461904    0.492380     0.789608         0
# 4    0.724325   0.605172    0.713202     0.817874         0

# %%
# 确保 did_df 中的 Date 列为 'YYYY-MM' 格式
did_df['Date'] = did_df['year'].astype(str) + '-' + did_df['month'].astype(str).str.zfill(2)

# 检查 traffic_df 和 did_df 的 Date 列，确保格式一致
print("Unique dates in traffic_df:", traffic_df['Date'].unique())  # 查看 traffic_df 中的日期格式
print("Unique dates in did_df:", did_df['Date'].unique())  # 查看 did_df 中的日期格式
# Out:
# Unique dates in traffic_df: ['2018-01' '2018-02' '2018-03' '2018-04' '2018-05' '2018-06' '2018-07'
#  '2018-08' '2018-09' '2018-10' '2018-11' '2018-12' '2019-01' '2019-02'
#  '2019-03' '2019-04' '2019-05' '2019-06' '2019-07' '2019-08' '2019-09'
#  '2019-10' '2019-11' '2019-12' '2020-01' '2020-02' '2020-03' '2020-04'
#  '2020-05' '2020-06' '2020-07' '2020-08' '2020-09' '2020-10' '2020-11'
#  '2020-12' '2021-01' '2021-02' '2021-03' '2021-04' '2021-05' '2021-06'
#  '2021-07' '2021-08' '2021-09' '2021-10' '2021-11' '2021-12' '2022-01'
#  '2022-02' '2022-03' '2022-04' '2022-05' '2022-06' '2022-07' '2022-08'
#  '2022-09' '2022-10' '2022-11' '2022-12']
# Unique dates in did_df: ['2018-01' '2018-02' '2018-03' '2018-04' '2018-05' '2018-06' '2018-07'
#  '2018-08' '2018-09' '2018-10' '2018-11' '2018-12' '2019-01' '2019-02'
#  '2019-03' '2019-04' '2019-05' '2019-06' '2019-07' '2019-08' '2019-09'
#  '2019-10' '2019-11' '2019-12' '2020-01' '2020-02' '2020-03' '2020-04'
#  '2020-05' '2020-06' '2020-07' '2020-08' '2020-09' '2020-10' '2020-11'
#  '2020-12' '2021-01' '2021-02' '2021-03' '2021-04' '2021-05' '2021-06'
#  '2021-07' '2021-08' '2021-09' '2021-10' '2021-11' '2021-12' '2022-01'
#  '2022-02' '2022-03' '2022-04' '2022-05' '2022-06' '2022-07' '2022-08'
#  '2022-09' '2022-10' '2022-11' '2022-12']

# %%
# 处理政策处理信息（合并到主数据）
did_df['Date'] = did_df['year'].astype(str) + '-' + did_df['month'].astype(str).str.zfill(2)

# 检查合并数据的列名和缺失值
print("Missing values in merged data before did merge:\n", traffic_df.isnull().sum())

traffic_df = pd.merge(traffic_df, did_df[['COD_DIS', 'COD_BAR', 'Date', 'treati', 'postit', 'DID']], 
                      on=['COD_DIS', 'COD_BAR', 'Date'], how='left')

# 检查合并后的数据
print("Missing values after did merge:\n", traffic_df.isnull().sum())
# Out:
# Missing values in merged data before did merge:
#  COD_DIS                 0
# COD_BAR                 0
# Date                    0
# accident_rate_melted    0
# EDUCATION               0
# INCOME                  0
# POPULATION              0
# TRANSPORT               0
# COMMERCIAL              0
# RESIDENTIAL             0
# PANDEMIC                0
# dtype: int64
# Missing values after did merge:
#  COD_DIS                 0
# COD_BAR                 0
# Date                    0
# accident_rate_melted    0
# EDUCATION               0
# INCOME                  0
# POPULATION              0
# TRANSPORT               0
# COMMERCIAL              0
# RESIDENTIAL             0
# PANDEMIC                0
# treati                  0
# postit                  0
# DID                     0
# dtype: int64

# %%
# 确保没有空值，去除包含空值的行（根据需要调整）
traffic_df = traffic_df.dropna()

# 设置DiD模型公式
formula = 'accident_rate_melted ~ DID + EDUCATION + INCOME + POPULATION + TRANSPORT + COMMERCIAL + RESIDENTIAL + PANDEMIC + C(COD_BAR) + C(Date)'

# 使用`statsmodels`进行回归分析
model = smf.ols(formula=formula, data=traffic_df).fit()

# 保存结果到Excel文件
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    model_summary = model.summary2().tables[1]
    model_summary.to_excel(writer, sheet_name='DiD_Model_Results')
     
print(f'输出已保存至: {output_file}')
# Out:
# 输出已保存至: output_directory\DiD_model_results_2025-03-27_16-00-38.xlsx

# %%
    # 计算模型统计指标
model_stats = {
        "R-squared": model.rsquared,
        "Adj. R-squared": model.rsquared_adj,
        "F-statistic": model.fvalue,
        "Prob (F-statistic)": model.f_pvalue,
        "AIC": model.aic,
        "BIC": model.bic
    }
    # 保存结果到 Excel

stats_df = pd.DataFrame(model_stats.items(), columns=['Statistic', 'Value'])

print (stats_df.head())
# Out:
#             Statistic         Value
# 0           R-squared      0.688047
# 1      Adj. R-squared      0.680110
# 2         F-statistic     86.686091
# 3  Prob (F-statistic)      0.000000
# 4                 AIC  57641.865478
